# %%
# Minimum-distances 

n=int(input())
arr=list(map(int,input().split()))
min_diff=float('inf')
found=False
s=set(arr)

for x in s:
    index=[]
    for i in range(len(arr)):
        if arr[i]==x:
            index.append(i)

    if len(index)>1:
        for j in range(len(index)-1):
            d=index[j+1]-index[j]
            min_diff=min(min_diff,d)
            found=True
if found:
    print(min_diff)
else:
# Out:
#  6
#  7 1 2 4 1 7
# 3

# %%
Sample Input
7 1 2 4 1 7

STDIN           Function
-----           --------
6               arr[] size n = 6
C     arr = [7, 1, 3, 4, 1, 7]
Sample Output

3
