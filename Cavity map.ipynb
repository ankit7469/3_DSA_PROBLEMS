# %%
# Cavity map

n = int(input())
grid = []

for _ in range(n):
    grid.append(list(input()))

result = [row[:] for row in grid]

for i in range(1, n-1):                                 # cavity check
    for j in range(1, n-1):

        if (grid[i][j] > grid[i-1][j] and grid[i][j] > grid[i+1][j] and grid[i][j] > grid[i][j-1] and grid[i][j] > grid[i][j+1]):
            result[i][j] = 'X'

for row in result:                   # output 
    print("".join(row))
# Out:
#  4
#  1112

# %%
Sample Input

STDIN   Function
-----   --------
4       grid[] size n = 4
1112    grid = ['1112', '1912', '1892', '1234']
1912
1892
1234
Sample Output

1112
1X12
18X2
1234
