# %%
## Encryption 

import math

str1=input()
a=len(str1)
# print(a)
result=math.sqrt(a)

row=math.floor(result)             # for lower square root value (rows)
column=math.ceil(result)           # for upper square root value (column)

#print(result)
#print(row)
#print(column)

if row*column < a:                # for encryption necessary contion 
    row+=1

#print(row)
#print(column)

index=0

for c in range(column):             # column vise 
    for r in range(row):
        index=r*column +c
        if index< a:
            print(str1[index],end="")
    print(" ",end="")
# Out:
#  haveaniceday
# hae and via ecy

# %%
Sample Input 2

chillout
Sample Output 2

clu hlt io

# %%
## Encryption 

import math

str1=input()
a=len(str1)
# print(a)
result=math.sqrt(a)

row=math.floor(result)             # for lower square root value (rows)
column=math.ceil(result)           # for upper square root value (column)

#print(result)
#print(row)
#print(column)

if row*column < a:                # for encryption necessary contion 
    row+=1

#print(row)
#print(column)

index=0

             
for r in range(row):             # row vise 
    for c in range(column): 
        if index< a:
            print(str1[index],end="")
            index+=1|
    print()
# Out:
#   Cell In[28], line 30
#     index+=1|
#              ^
# SyntaxError: invalid syntax
